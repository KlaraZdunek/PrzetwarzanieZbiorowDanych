# %%
x = 5

# %%
print(x)
# Out:
# 5

# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # Pandas

# %%
movie_path = 'https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook/master/data/movie.csv'
movie = pd.read_csv(movie_path)
movie.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 movie_path = 'https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook/master/data/movie.csv'
# ----> 2 movie = pd.read_csv(movie_path)
#       3 movie.head()
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
movie_path = 'https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook/master/data/movie.csv'
movie = pd.read_csv(movie_path)
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
type(movie)
# Out:
# pandas.core.frame.DataFrame

# %%
movie.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %%
columns = movie.columns
index = movie.index
data = movie.values

# %%
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
data
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
X = np.random.randn(10,10)
X
# Out:
# array([[-0.26203964, -1.7904293 , -0.40494817, -0.65814572, -2.41505977,
#         -0.51924875, -2.73098473, -0.01631583,  0.2279429 , -0.40437821],
#        [ 0.11719504,  0.70960802, -0.72320211,  2.99028218, -0.93563745,
#          0.98599232, -1.5617199 , -0.09712746, -0.98231526,  1.4771196 ],
#        [-0.91105715,  0.20489851,  1.01959945, -0.31151487, -0.32342644,
#         -0.86934895, -0.23796217,  0.67226922,  0.04593727, -1.7328581 ],
#        [ 1.28840792, -2.14537557,  0.84740565, -0.53445678,  1.12590169,
#          0.72339725,  1.00574507, -0.23301764, -0.37963816, -0.57392067],
#        [ 0.27992906,  0.30970394,  0.73737184,  0.14907343,  0.62405725,
#         -0.35770908, -0.3465649 ,  0.33181349, -0.76521008, -0.30977173],
#        [ 0.79810583,  0.92119641,  0.21927239,  0.61787614,  0.333918  ,
#         -0.30182574, -0.88410759,  0.57092405, -0.58781465,  2.95991442],
#        [ 0.75910704,  0.50500772, -0.03217561,  0.84437477, -0.66980044,
# ...

# %%
pd.DataFrame(X)
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.262040 -1.790429 -0.404948 -0.658146 -2.415060 -0.519249 -2.730985
# 1  0.117195  0.709608 -0.723202  2.990282 -0.935637  0.985992 -1.561720
# 2 -0.911057  0.204899  1.019599 -0.311515 -0.323426 -0.869349 -0.237962
# 3  1.288408 -2.145376  0.847406 -0.534457  1.125902  0.723397  1.005745
# 4  0.279929  0.309704  0.737372  0.149073  0.624057 -0.357709 -0.346565
# 5  0.798106  0.921196  0.219272  0.617876  0.333918 -0.301826 -0.884108
# 6  0.759107  0.505008 -0.032176  0.844375 -0.669800 -1.616674  0.171408
# 7 -0.767541  0.026793 -0.262331  0.506672 -0.194407 -0.372315 -0.142992
# 8  1.293562 -0.153052  0.423499  0.152738 -0.471128  2.080047 -1.175871
# 9 -1.577747 -1.067318  2.372329  1.010686  1.307375  0.110595  0.618971
#
#           7         8         9
# 0 -0.016316  0.227943 -0.404378
# 1 -0.097127 -0.982315  1.477120
# 2  0.672269  0.045937 -1.732858
# 3 -0.233018 -0.379638 -0.573921
# ...

# %%
X = np.random.randn(3,3)

# %%
x3 = np.random.randn(3,3)
df = pd.DataFrame(X3, columns= ['col_1','col_2','col_3'], index = ['idx_a', 'idx_b', 'idx_c']
df
# Out:
#   Input In [16]
#     df = pd.DataFrame(X3, columns= ['col_1','col_2','col_3'], index = ['idx_a', 'idx_b', 'idx_c']
#                      ^
# SyntaxError: '(' was never closed

# %%
x3 = np.random.randn(3,3)
df = pd.DataFrame(X3, columns= ['col_1','col_2','col_3'], index = ['idx_a', 'idx_b', 'idx_c'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 2>()
#       1 x3 = np.random.randn(3,3)
# ----> 2 df = pd.DataFrame(X3, columns= ['col_1','col_2','col_3'], index = ['idx_a', 'idx_b', 'idx_c'])
#       3 df
#
# NameError: name 'X3' is not defined

# %%
x3 = np.random.randn(3,3)
df = pd.DataFrame(x3, columns= ['col_1','col_2','col_3'], index = ['idx_a', 'idx_b', 'idx_c'])
df
# Out:
#           col_1     col_2     col_3
# idx_a  0.391832 -0.916794  0.993760
# idx_b -1.292937  0.440313  1.297477
# idx_c  1.237569 -0.245232  1.337891

# %%
df_1 = pd.DataFrame({
    'kamil': [1,2,3]
    'asia': [3,4,5]
})
df_1
# Out:
#   Input In [19]
#     'kamil': [1,2,3]
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df_1 = pd.DataFrame({
    'kamil': [1,2,3],
    'asia': [3,4,5]
})
df_1
# Out:
#    kamil  asia
# 0      1     3
# 1      2     4
# 2      3     5

# %%
movie.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# ##Series

# %% [markdown]
# #Series

# %%
movie.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# ...

# %%
movie['num_critic_for_reviews']
# Out:
# 0       723.0
# 1       302.0
# 2       602.0
# 3       813.0
# 4         NaN
#         ...
# 4911      1.0
# 4912     43.0
# 4913     13.0
# 4914     14.0
# 4915     43.0
# Name: num_critic_for_reviews, Length: 4916, dtype: float64

# %%
type(director)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 type(director)
#
# NameError: name 'director' is not defined

# %%
numery = movie['num_critic_for_reviews']
numery.name
# Out:
# 'num_critic_for_reviews'

# %%
type[numery]
# Out:
# type[0       723.0
# 1       302.0
# 2       602.0
# 3       813.0
# 4         NaN
#         ...
# 4911      1.0
# 4912     43.0
# 4913     13.0
# 4914     14.0
# 4915     43.0
# Name: num_critic_for_reviews, Length: 4916, dtype: float64]

# %%
type(numery)
# Out:
# pandas.core.series.Series

# %%
numery.value_counts()
# Out:
# 1.0      40
# 5.0      36
# 9.0      36
# 10.0     34
# 8.0      34
#          ..
# 775.0     1
# 552.0     1
# 502.0     1
# 510.0     1
# 409.0     1
# Name: num_critic_for_reviews, Length: 528, dtype: int64

# %%
movie.shape
# Out:
# (4916, 28)

# %%
numery.shape
# Out:
# (4916,)

# %%
movie.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  \
# 4911                   637.0      NaN                  Comedy|Drama
# ...

# %%
# !mkdir data

# %% [markdown]
# # Index

# %%
movie.to_csv('data/movie.csv', sep=',', index_col='movie_title')

# %%
movie = pd.read_csv('data/movie.csv', sep=',', index_col='movie_title')
movie.head()
# Out:
#                                             Unnamed: 0  color  \
# movie_title
# Avatar                                               0  Color
# Pirates of the Caribbean: At World's End             1  Color
# Spectre                                              2  Color
# The Dark Knight Rises                                3  Color
# Star Wars: Episode VII - The Force Awakens           4    NaN
#
#                                                 director_name  \
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# ...

# %%
movie.shape
# Out:
# (4916, 29)

# %%
movie.to_csv('data/movie.csv', index=False)

# %%
movie.to_pickle('data/movie.pkl')

# %%
movie.index
# Out:
# Index(['Avatar', 'Pirates of the Caribbean: At World's End', 'Spectre',
#        'The Dark Knight Rises', 'Star Wars: Episode VII - The Force Awakens',
#        'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron',
#        'Harry Potter and the Half-Blood Prince',
#        ...
#        'Primer', 'Cavite', 'El Mariachi', 'The Mongol King', 'Newlyweds',
#        'Signed Sealed Delivered', 'The Following', 'A Plague So Pleasant',
#        'Shanghai Calling', 'My Date with Drew'],
#       dtype='object', name='movie_title', length=4916)

# %%
movie.columns
# Out:
# Index(['Unnamed: 0', 'color', 'director_name', 'num_critic_for_reviews',
#        'duration', 'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres',
#        'actor_1_name', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movie.head()
# Out:
#                                             Unnamed: 0  color  \
# movie_title
# Avatar                                               0  Color
# Pirates of the Caribbean: At World's End             1  Color
# Spectre                                              2  Color
# The Dark Knight Rises                                3  Color
# Star Wars: Episode VII - The Force Awakens           4    NaN
#
#                                                 director_name  \
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# ...

# %%
movie = movie.reset_index()

# %%
movie.head()
# Out:
#                                   movie_title  Unnamed: 0  color  \
# 0                                      Avatar           0  Color
# 1    Pirates of the Caribbean: At World's End           1  Color
# 2                                     Spectre           2  Color
# 3                       The Dark Knight Rises           3  Color
# 4  Star Wars: Episode VII - The Force Awakens           4    NaN
#
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 4        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# ...

# %%
movie.set_index('director_name')
# Out:
#                                                   movie_title  Unnamed: 0  \
# director_name
# James Cameron                                          Avatar           0
# Gore Verbinski       Pirates of the Caribbean: At World's End           1
# Sam Mendes                                            Spectre           2
# Christopher Nolan                       The Dark Knight Rises           3
# Doug Walker        Star Wars: Episode VII - The Force Awakens           4
# ...                                                       ...         ...
# Scott Smith                           Signed Sealed Delivered        4911
# NaN                                             The Following        4912
# Benjamin Roberds                         A Plague So Pleasant        4913
# Daniel Hsia                                  Shanghai Calling        4914
# Jon Gunn                                    My Date with Drew        4915
#
#                    color  num_critic_for_reviews  duration  \
# ...

# %%
movie = movie.reset_index()

# %%
movie.head()
# Out:
#    index                                 movie_title  Unnamed: 0  color  \
# 0      0                                      Avatar           0  Color
# 1      1    Pirates of the Caribbean: At World's End           1  Color
# 2      2                                     Spectre           2  Color
# 3      3                       The Dark Knight Rises           3  Color
# 4      4  Star Wars: Episode VII - The Force Awakens           4    NaN
#
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 4        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# ...

# %%
movie.sort_values('duration')
# Out:
#       index                           movie_title  Unnamed: 0  color  \
# 2316   2316                             The Touch        2316  Color
# 1930   1930                       Shaun the Sheep        1930  Color
# 3997   3997                         Robot Chicken        3997  Color
# 4564   4564                                Vessel        4564  Color
# 4342   4342  Wal-Mart: The High Cost of Low Price        4342  Color
# ...     ...                                   ...         ...    ...
# 4416   4416                            Wolf Creek        4416  Color
# 4502   4502                     Karachi se Lahore        4502  Color
# 4580   4580                               Destiny        4580  Color
# 4825   4825                      Romantic Schemer        4825  Color
# 4863   4863                         The Naked Ape        4863  Color
#
#          director_name  num_critic_for_reviews  duration  \
# 2316        Jane Clark                     NaN       7.0
# ...

# %%
movie.reset_index(drop=True)
# Out:
#       index                                 movie_title  Unnamed: 0  color  \
# 0         0                                      Avatar           0  Color
# 1         1    Pirates of the Caribbean: At World's End           1  Color
# 2         2                                     Spectre           2  Color
# 3         3                       The Dark Knight Rises           3  Color
# 4         4  Star Wars: Episode VII - The Force Awakens           4    NaN
# ...     ...                                         ...         ...    ...
# 4911   4911                     Signed Sealed Delivered        4911  Color
# 4912   4912                               The Following        4912  Color
# 4913   4913                        A Plague So Pleasant        4913  Color
# 4914   4914                            Shanghai Calling        4914  Color
# 4915   4915                           My Date with Drew        4915  Color
#
#           director_name  num_critic_for_reviews  duration  \
# ...

# %%
movie = movie.sort_values('duration', ascending=True)

# %%
movie
# Out:
#       index                           movie_title  Unnamed: 0  color  \
# 2316   2316                             The Touch        2316  Color
# 1930   1930                       Shaun the Sheep        1930  Color
# 3997   3997                         Robot Chicken        3997  Color
# 4564   4564                                Vessel        4564  Color
# 4342   4342  Wal-Mart: The High Cost of Low Price        4342  Color
# ...     ...                                   ...         ...    ...
# 4416   4416                            Wolf Creek        4416  Color
# 4502   4502                     Karachi se Lahore        4502  Color
# 4580   4580                               Destiny        4580  Color
# 4825   4825                      Romantic Schemer        4825  Color
# 4863   4863                         The Naked Ape        4863  Color
#
#          director_name  num_critic_for_reviews  duration  \
# 2316        Jane Clark                     NaN       7.0
# ...

# %%
movie
# Out:
#       index                           movie_title  Unnamed: 0  color  \
# 2316   2316                             The Touch        2316  Color
# 1930   1930                       Shaun the Sheep        1930  Color
# 3997   3997                         Robot Chicken        3997  Color
# 4564   4564                                Vessel        4564  Color
# 4342   4342  Wal-Mart: The High Cost of Low Price        4342  Color
# ...     ...                                   ...         ...    ...
# 4416   4416                            Wolf Creek        4416  Color
# 4502   4502                     Karachi se Lahore        4502  Color
# 4580   4580                               Destiny        4580  Color
# 4825   4825                      Romantic Schemer        4825  Color
# 4863   4863                         The Naked Ape        4863  Color
#
#          director_name  num_critic_for_reviews  duration  \
# 2316        Jane Clark                     NaN       7.0
# ...
